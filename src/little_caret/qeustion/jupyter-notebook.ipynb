# %%
import sys
sys.path.append('/home/emb4/sample_system/src')

from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()

data = {
    'tako' : [1, 2, 3, 4, 5],
}
interface = Interface(data)
print(interface.data) # ←interface.dataはpropetyなのでinterface.data()とやらないで参照できる
interface.line_plot()

new_data = {
    'kani' : [5, 2, 4, 5, 1],
}

data.update(new_data)
interface = Interface(data)
print(interface.data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# {'tako': [1, 2, 3, 4, 5]}
#   <div class="bk-root" id="4e95e052-59ee-4f45-acfc-032fd58e226f" data-root-id="1003"></div>
# {'tako': [1, 2, 3, 4, 5], 'kani': [5, 2, 4, 5, 1]}
#   <div class="bk-root" id="1291ef78-e5a1-4a83-810a-df0fa0cd02e5" data-root-id="1103"></div>

# %%
# Q02: 下記のコードを実行して動くようにせよ
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
}
new_data = {
    'ika' : [3, 4, 5, 0, 2],
    'uni' : [2, 4, 6, 4, 3],
}

interface = Interface(data)
interface.data_append(new_data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1219">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a3a01f4f-7f4d-4a18-9fa4-079fa7b241c4" data-root-id="1220"></div>

# %%
# Q03: 折れ線グラフではなく、棒グラフで表示できるように実装せよ
# ヒント: 設計思想を意識せよ
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
}
interface = Interface(data)
interface.bar_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1352">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="36399ca7-375d-4b75-a67f-b4bdda0835ee" data-root-id="1353"></div>

# %%
# Q05: 一本一本の線を異なる色で表示させよ
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
    'ika' : [3, 4, 5, 0, 2],
    'uni' : [2, 4, 6, 4, 3],
}

interface = Interface(data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1483">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="15adb19f-5222-4d3c-ba5b-58605b367a98" data-root-id="1484"></div>
