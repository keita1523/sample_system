# %%
import sys
sys.path.append('/home/emb4/sample_system/src')

from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()

data = {
    'tako' : [1, 2, 3, 4, 5],
}
interface = Interface(data)
print(interface.data) # ←interface.dataはpropetyなのでinterface.data()とやらないで参照できる
interface.line_plot()

new_data = {
    'kani' : [5, 2, 4, 5, 1],
}

data.update(new_data)
interface = Interface(data)
print(interface.data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1219">Loading BokehJS ...</span>
#     </div>
# {'tako': [1, 2, 3, 4, 5]}
#   <div class="bk-root" id="53150986-de82-4eff-aa1a-40b6b3fb747e" data-root-id="1220"></div>
# {'tako': [1, 2, 3, 4, 5], 'kani': [5, 2, 4, 5, 1]}
#   <div class="bk-root" id="921dc218-ed6d-44a3-8ca1-a0d04f09d841" data-root-id="1340"></div>

# %%
# Q02: 下記のコードを実行して動くようにせよ
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
}
new_data = {
    'ika' : [3, 4, 5, 0, 2],
    'uni' : [2, 4, 6, 4, 3],
}

interface = Interface(data)
interface.data_append(new_data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1476">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /home/emb4/sample_system/src/little_caret/jupyter/jupyter-notebook.ipynb Cell 2 in 1
#       <a href='vscode-notebook-cell:/home/emb4/sample_system/src/little_caret/jupyter/jupyter-notebook.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> new_data = {
#       <a href='vscode-notebook-cell:/home/emb4/sample_system/src/little_caret/jupyter/jupyter-notebook.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>     'ika' : [3, 4, 5, 0, 2],
#      <a href='vscode-notebook-cell:/home/emb4/sample_system/src/little_caret/jupyter/jupyter-notebook.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a>     'uni' : [2, 4, 6, 4, 3],
# ...

# %%
# Q03: 折れ線グラフではなく、棒グラフで表示できるように実装せよ
# ヒント: 設計思想を意識せよ
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
}
interface = Interface(data)
interface.bar_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1477">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /home/emb4/sample_system/src/little_caret/jupyter/jupyter-notebook.ipynb Cell 3 in 1
#       <a href='vscode-notebook-cell:/home/emb4/sample_system/src/little_caret/jupyter/jupyter-notebook.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> data = {
#       <a href='vscode-notebook-cell:/home/emb4/sample_system/src/little_caret/jupyter/jupyter-notebook.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>     'tako' : [1, 2, 3, 4, 5],
#       <a href='vscode-notebook-cell:/home/emb4/sample_system/src/little_caret/jupyter/jupyter-notebook.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> }
# ...

# %%
# Q05: 一本一本の線を異なる色で表示させよ （難しいのでやらなくて良い）
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
    'ika' : [3, 4, 5, 0, 2],
    'uni' : [2, 4, 6, 4, 3],
}

interface = Interface(data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1478">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="11066f34-ca5a-498a-81a4-11248867abcb" data-root-id="1479"></div>
