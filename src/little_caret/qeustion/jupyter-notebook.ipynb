# %%
import sys
sys.path.append('/home/emb4/sample_system/src')

from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()

data = {
    'tako' : [1, 2, 3, 4, 5],
}
interface = Interface(data)
print(interface.data) # ←interface.dataはpropetyなのでinterface.data()とやらないで参照できる
interface.line_plot()

new_data = {
    'kani' : [5, 2, 4, 5, 1],
}

data.update(new_data)
interface = Interface(data)
print(interface.data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# {'tako': [1, 2, 3, 4, 5]}
#   <div class="bk-root" id="5c83e133-ad95-4af8-b8dc-09bdfb4466e8" data-root-id="1003"></div>
# {'tako': [1, 2, 3, 4, 5], 'kani': [5, 2, 4, 5, 1]}
#   <div class="bk-root" id="eaf4a71b-259d-456a-bd5b-1ffedac47d6f" data-root-id="1103"></div>

# %%
# Q02: 下記のコードを実行して動くようにせよ
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
}
new_data = {
    'ika' : [3, 4, 5, 0, 2],
    'uni' : [2, 4, 6, 4, 3],
}

interface = Interface(data)
interface.data_append(new_data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1219">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="656d9465-a0b7-4810-be3d-1a828ba0e512" data-root-id="1220"></div>

# %%
# Q03: 折れ線グラフではなく、棒グラフで表示できるように実装せよ
# ヒント: 設計思想を意識せよ
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
}
interface = Interface(data)
interface.bar_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1793">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c779e383-28c7-4e6c-8e8e-226ae76b7fd0" data-root-id="1794"></div>

# %%
# Q05: 一本一本の線を異なる色で表示させよ
from little_caret.interface.interface import Interface
from bokeh.io import output_notebook
output_notebook()
data = {
    'tako' : [1, 2, 3, 4, 5],
    'ika' : [3, 4, 5, 0, 2],
    'uni' : [2, 4, 6, 4, 3],
}

interface = Interface(data)
interface.line_plot()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1489">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="983e2cbd-7ed6-441c-8f5a-d5bbca569ffc" data-root-id="1490"></div>
